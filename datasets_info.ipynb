# %%
from ucimlrepo import fetch_ucirepo
import pandas as pd
import numpy as np

# %%
# Dataset that seems useful
dataset_id = {
    "iris": 53, 
    "heart_disease": 45, 
    "wine_quality": 186, 
    "breast_cancer_wisconsin_diagnostic": 17, 
    "car_evaluation": 19, 
    "spect_heart" : 95, 
    "spectf_heart" : 96,
    "mushroom": 73, 
    "statlog" : 144, 
    "credit_approval" : 27, 
    "zoo" : 111, 
    "balance_scale" : 12, 
    "ilpd" : 225, 
    "acute_inflamations" : 184, 
    "ecoli" : 39, 
    "mammographic_mass" : 161, 
    "hayes_roth" : 44, 
    "habermans_survival" : 43, 
    "congress_voting_records" : 105, 
    "balloons" : 13, 
    "lenses" : 58, 
    "fertility" : 244, 
}

# sort alphabetically and adds id for logging
data_set_sorted = {}
for i, name in enumerate(sorted(dataset_id.keys())):
    data_set_sorted[name] = (dataset_id[name], i+1)

print(data_set_sorted)
# Out:
# {'acute_inflamations': (184, 1), 'balance_scale': (12, 2), 'balloons': (13, 3), 'breast_cancer_wisconsin_diagnostic': (17, 4), 'car_evaluation': (19, 5), 'congress_voting_records': (105, 6), 'credit_approval': (27, 7), 'ecoli': (39, 8), 'fertility': (244, 9), 'habermans_survival': (43, 10), 'hayes_roth': (44, 11), 'heart_disease': (45, 12), 'ilpd': (225, 13), 'iris': (53, 14), 'lenses': (58, 15), 'mammographic_mass': (161, 16), 'mushroom': (73, 17), 'spect_heart': (95, 18), 'spectf_heart': (96, 19), 'statlog': (144, 20), 'wine_quality': (186, 21), 'zoo': (111, 22)}

# %%
for (name, id) in data_set_sorted.items():
    print("*"*100)
    # get the dataset
    dataset = fetch_ucirepo(id=id[0]) 
    # load data into dataframe for easier preprocessing
    df = pd.concat([dataset["data"]["features"],dataset["data"]["targets"] ],axis=1)
    print(f"Name of dataset: {name}")
    print(f"Number of classes: {len(np.unique(df.iloc[:,-1:]))}")
    class_numbers = df.iloc[:,-1:].value_counts()
    print(f"Percentage of majority class: {np.max(class_numbers)/df.shape[0]}")
    print("*"*100, end="\n\n")
# Out:
# ****************************************************************************************************
# Name of dataset: acute_inflamations
# Number of classes: 2
# Percentage of majority class: 0.5833333333333334
# ****************************************************************************************************
#
# ****************************************************************************************************
# Name of dataset: balance_scale
# Number of classes: 3
# Percentage of majority class: 0.4608
# ****************************************************************************************************
#
# ****************************************************************************************************
# Name of dataset: balloons
# Number of classes: 2
# Percentage of majority class: 0.5625
# ****************************************************************************************************
#
# ****************************************************************************************************
# Name of dataset: breast_cancer_wisconsin_diagnostic
# Number of classes: 2
# Percentage of majority class: 0.6274165202108963
# ****************************************************************************************************
#
# ****************************************************************************************************
# Name of dataset: car_evaluation
# Number of classes: 4
# Percentage of majority class: 0.7002314814814815
# ****************************************************************************************************
#
# ****************************************************************************************************
# Name of dataset: congress_voting_records
# Number of classes: 2
# Percentage of majority class: 0.6137931034482759
# ****************************************************************************************************
#
# ****************************************************************************************************
# Name of dataset: credit_approval
# Number of classes: 2
# Percentage of majority class: 0.5550724637681159
# ****************************************************************************************************
#
# ****************************************************************************************************
# Name of dataset: ecoli
# Number of classes: 8
# Percentage of majority class: 0.4255952380952381
# ****************************************************************************************************
#
# ****************************************************************************************************
# Name of dataset: fertility
# Number of classes: 2
# Percentage of majority class: 0.88
# ****************************************************************************************************
#
# ****************************************************************************************************
# Name of dataset: habermans_survival
# Number of classes: 2
# Percentage of majority class: 0.7352941176470589
# ****************************************************************************************************
#
# ****************************************************************************************************
# Name of dataset: hayes_roth
# Number of classes: 4
# Percentage of majority class: 0.31875
# ****************************************************************************************************
#
# ****************************************************************************************************
# Name of dataset: heart_disease
# Number of classes: 5
# Percentage of majority class: 0.5412541254125413
# ****************************************************************************************************
#
# ****************************************************************************************************
# Name of dataset: ilpd
# Number of classes: 2
# Percentage of majority class: 0.7135506003430532
# ****************************************************************************************************
#
# ****************************************************************************************************
# Name of dataset: iris
# Number of classes: 3
# Percentage of majority class: 0.3333333333333333
# ****************************************************************************************************
#
# ****************************************************************************************************
# Name of dataset: lenses
# Number of classes: 3
# Percentage of majority class: 0.625
# ****************************************************************************************************
#
# ****************************************************************************************************
# Name of dataset: mammographic_mass
# Number of classes: 2
# Percentage of majority class: 0.5369406867845994
# ****************************************************************************************************
#
# ****************************************************************************************************
# Name of dataset: mushroom
# Number of classes: 2
# Percentage of majority class: 0.517971442639094
# ****************************************************************************************************
#
# ****************************************************************************************************
# Name of dataset: spect_heart
# Number of classes: 2
# Percentage of majority class: 0.7940074906367042
# ****************************************************************************************************
#
# ****************************************************************************************************
# Name of dataset: spectf_heart
# Number of classes: 2
# Percentage of majority class: 0.7940074906367042
# ****************************************************************************************************
#
# ****************************************************************************************************
# Name of dataset: statlog
# Number of classes: 2
# Percentage of majority class: 0.7
# ****************************************************************************************************
#
# ****************************************************************************************************
# Name of dataset: wine_quality
# Number of classes: 7
# Percentage of majority class: 0.43650915807295676
# ****************************************************************************************************
#
# ****************************************************************************************************
# Name of dataset: zoo
# Number of classes: 7
# Percentage of majority class: 0.40594059405940597
# ****************************************************************************************************
